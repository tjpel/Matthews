# %%
'''import pandas as pd
from sklearn import datasets

df = datasets.load_diabetes() # loading data
type(df) # getting data type'''
# Out:
# sklearn.utils._bunch.Bunch

# %%
'''diabetes = pd.DataFrame(data=df.data, columns = df.feature_names) # makes it a dataframe rather than an sklearn object
diabetes['target'] = df.target

diabetes.head()'''
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
'''from vega_datasets import local_data
local_data.list_datasets() # lists available datasets'''
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from vega_datasets import local_data
#       2 local_data.list_datasets() # lists available datasets
#
# ModuleNotFoundError: No module named 'vega_datasets'

# %%
import pandas as pd
data = pd.read_csv("/Users/lehergulati/Downloads/CostarExport_1.csv") # getting the data

# %%
df = pd.DataFrame(data) # converting to dataframe
# print(data) # printing what we have

data.head()
# Out:
#           Property Address Property City Property State Property County  \
# 0            1241 Irolo St   Los Angeles             CA     Los Angeles
# 1          722 Robinson St   Los Angeles             CA     Los Angeles
# 2    1821 S New England St   Los Angeles             CA     Los Angeles
# 3  1510-1514 S Cochran Ave   Los Angeles             CA     Los Angeles
# 4         951 S Berendo St   Los Angeles             CA     Los Angeles
#
#   Property Zip Code Property Type  Sale Price Sale Price Comment  \
# 0             90006  Multi-Family  $2,990,000          Confirmed
# 1        90026-3615  Multi-Family  $1,460,000         Full Value
# 2        90006-5313  Multi-Family  $2,950,000          Confirmed
# 3        90019-4068  Multi-Family  $2,830,602          Confirmed
# 4             90006  Multi-Family  $1,750,000          Confirmed
#
#    Number Of Units   Size  ... Parcel Number 1 (Min) Parcel Number 2 (Max)  \
# ...

# %%
df.head()
# Out:
#           Property Address Property City Property State Property County  \
# 0            1241 Irolo St   Los Angeles             CA     Los Angeles
# 1          722 Robinson St   Los Angeles             CA     Los Angeles
# 2    1821 S New England St   Los Angeles             CA     Los Angeles
# 3  1510-1514 S Cochran Ave   Los Angeles             CA     Los Angeles
# 4         951 S Berendo St   Los Angeles             CA     Los Angeles
#
#   Property Zip Code Property Type  Sale Price Sale Price Comment  \
# 0             90006  Multi-Family  $2,990,000          Confirmed
# 1        90026-3615  Multi-Family  $1,460,000         Full Value
# 2        90006-5313  Multi-Family  $2,950,000          Confirmed
# 3        90019-4068  Multi-Family  $2,830,602          Confirmed
# 4             90006  Multi-Family  $1,750,000          Confirmed
#
#    Number Of Units   Size  ... Parcel Number 1 (Min) Parcel Number 2 (Max)  \
# ...

# %%
df.tail()
# Out:
#                        Property Address Property City Property State  \
# 467                      1950 West Blvd   Los Angeles             CA
# 468                608 S St Andrews Plz   Los Angeles             CA
# 469                 614 S St Andrews Pl   Los Angeles             CA
# 470                 620 S St Andrews Pl   Los Angeles             CA
# 471  620 S St Andrews Pl (4 Properties)   Los Angeles             CA
#
#     Property County Property Zip Code Property Type Sale Price  \
# 467     Los Angeles        90016-1720  Multi-Family   $649,000
# 468     Los Angeles        90005-3098  Multi-Family        NaN
# 469     Los Angeles        90005-3067  Multi-Family        NaN
# 470     Los Angeles        90005-3029  Multi-Family        NaN
# 471     Los Angeles        90005-3029           NaN        NaN
#
#     Sale Price Comment  Number Of Units     Size  ... Parcel Number 1 (Min)  \
# 467                NaN                3    2,901  ...          5061-008-010
# ...

# %%
df.head(10)
# Out:
#           Property Address Property City Property State Property County  \
# 0            1241 Irolo St   Los Angeles             CA     Los Angeles
# 1          722 Robinson St   Los Angeles             CA     Los Angeles
# 2    1821 S New England St   Los Angeles             CA     Los Angeles
# 3  1510-1514 S Cochran Ave   Los Angeles             CA     Los Angeles
# 4         951 S Berendo St   Los Angeles             CA     Los Angeles
# 5           1452 W 20th St   Los Angeles             CA     Los Angeles
# 6         2421 Carmona Ave   Los Angeles             CA     Los Angeles
# 7     220-238 Roselake Ave   Los Angeles             CA     Los Angeles
# 8             2516 Kent St   Los Angeles             CA     Los Angeles
# 9        506 N Madison Ave   Los Angeles             CA     Los Angeles
#
#   Property Zip Code Property Type  Sale Price Sale Price Comment  \
# 0             90006  Multi-Family  $2,990,000          Confirmed
# ...

# %%
df.sort_values("Sale Price", ascending=False)
# Out:
#                        Property Address Property City Property State  \
# 158                    4108 Venice Blvd   Los Angeles             CA
# 465                        1613 6th Ave   Los Angeles             CA
# 91                   2846 S Bronson Ave   Los Angeles             CA
# 263               1427 S Bonnie Brae St   Los Angeles             CA
# 331                     1523 Cambria St   Los Angeles             CA
# ..                                  ...           ...            ...
# 224                660 S Cloverdale Ave   Los Angeles             CA
# 468                608 S St Andrews Plz   Los Angeles             CA
# 469                 614 S St Andrews Pl   Los Angeles             CA
# 470                 620 S St Andrews Pl   Los Angeles             CA
# 471  620 S St Andrews Pl (4 Properties)   Los Angeles             CA
#
#     Property County Property Zip Code Property Type Sale Price  \
# 158     Los Angeles             90019  Multi-Family   $969,000
# ...

# %%
df.sort_values("Daily", ascending=False)
# Out:
#                  Artist   Streams   Daily   As lead      Solo As feature
# 2          Taylor Swift  57,859.0  85.793  55,566.7  50,425.7    2,292.4
# 101      Olivia Rodrigo  12,161.1  71.896  12,159.0  10,909.5        2.1
# 0                 Drake  85,041.3  50.775  57,252.6  32,681.6   27,788.7
# 1             Bad Bunny  67,533.0  44.820  40,969.6  23,073.0   26,563.4
# 3            The Weeknd  53,665.2  44.437  42,673.3  31,164.2   10,991.9
# ...                 ...       ...     ...       ...       ...        ...
# 2080  The Lonely Island   1,036.3     NaN   1,007.7     291.2       28.7
# 2251      Mayday Parade     960.8     NaN     960.8     957.5        NaN
# 2800        Amon Amarth     778.4     NaN     778.4     771.4        NaN
# 2813          Tom Waits     776.7     NaN     773.3     769.9        3.3
# 2946       JayDaYoungan     741.4     NaN     724.3     626.1       17.0
#
# [3000 rows x 6 columns]

# %%
X = data.iloc[:, 0:2].values
Y = data.iloc[:, 1].values.reshape(-1,1)

# iloc is integer location
#   usage is .iloc(rowStart:rowEnd, columnStart:columnEnd) (not including endpoint)

# %%
print("X: ")
print(X.shape)
print("Y: ")
print(Y.shape)
# Out:
# X:
# (472, 2)
# Y:
# (472, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2, random_state = 2023)

# %%
from xgboost import XGBRegressor
xgb_model = XGBRegressor(random_state = 2023)

# %%
# make a dictionary of hyperparamater values to search
search_space = {
    "n_estimators": 
}
